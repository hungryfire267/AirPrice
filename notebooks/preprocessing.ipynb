# %%
import pandas as pd

# %%
listings_df = pd.read_csv(r"C:\Users\Gordon Li\Desktop\AirPrice\AirPrice\data\listings.csv")
listings_df.shape
# Out:
# (7125, 79)

# %%
import re

# %%
host_columns = [] 
for feature in listings_df.columns:
    if re.search("^host_.*", feature): 
        host_columns.append(feature)

# %%
host_listings = listings_df.loc[:, host_columns]
host_listings.head()
# Out:
#    host_id                                   host_url     host_name  \
# 0   850132   https://www.airbnb.com/users/show/850132       Maureen
# 1  1547968  https://www.airbnb.com/users/show/1547968           Ben
# 2   603365   https://www.airbnb.com/users/show/603365  Tony & Patty
# 3  2173713  https://www.airbnb.com/users/show/2173713       Lorelle
# 4  3355245  https://www.airbnb.com/users/show/3355245  Anne Therese
#
#    host_since            host_location  \
# 0  2011-07-21  Coolum Beach, Australia
# 1  2011-12-29    Peachester, Australia
# 2  2011-05-19     Montville, Australia
# 3  2012-04-19       Buddina, Australia
# 4  2012-08-23        Cooroy, Australia
#
#                                           host_about  host_response_time  \
# 0  We have travelled all over the world and lived...        within a day
# 1  I moved to iconic Mango Hill Farm in 2017. Sin...        within a day
# 2  We are both semi-retired and live in a beautif...  within a few hours
# ...

# %%
host_columns_remove = [
    "host_id", 
    ""
    
    
]
# Out:
# host_identity_verified
# t    6604
# f     520
# Name: count, dtype: int64

# %%
listings_df.iloc[:, 103:20]
# Out:
#                                          host_url     host_name  host_since  \
# 0        https://www.airbnb.com/users/show/850132       Maureen  2011-07-21
# 1       https://www.airbnb.com/users/show/1547968           Ben  2011-12-29
# 2        https://www.airbnb.com/users/show/603365  Tony & Patty  2011-05-19
# 3       https://www.airbnb.com/users/show/2173713       Lorelle  2012-04-19
# 4       https://www.airbnb.com/users/show/3355245  Anne Therese  2012-08-23
# ...                                           ...           ...         ...
# 7120  https://www.airbnb.com/users/show/154273143       Rebekah  2017-10-12
# 7121  https://www.airbnb.com/users/show/342848966    Noosa Blue  2020-03-30
# 7122  https://www.airbnb.com/users/show/327130252       Melanie  2020-01-13
# 7123  https://www.airbnb.com/users/show/444837087     Alexandra  2022-02-13
# 7124  https://www.airbnb.com/users/show/154273143       Rebekah  2017-10-12
#
#                   host_location  \
# ...
