# %%
import pandas as pd

# %%
listings_df = pd.read_csv(r"C:\Users\Gordon Li\Desktop\AirPrice\AirPrice\data\listings.csv")
listings_df.shape
# Out:
# (7125, 79)

# %%
listings_df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  177754  https://www.airbnb.com/rooms/177754  20250531151800   2025-05-31
# 1  300526  https://www.airbnb.com/rooms/300526  20250531151800   2025-05-31
# 2  368309  https://www.airbnb.com/rooms/368309  20250531151800   2025-05-31
# 3  437524  https://www.airbnb.com/rooms/437524  20250531151800   2025-05-31
# 4  664330  https://www.airbnb.com/rooms/664330  20250531151800   2025-05-31
#
#         source                                              name  \
# 0  city scrape    Coolum Ocean Views, 6 guests at no extra cost!
# 1  city scrape                       Tiny Farm House on The Hill
# 2  city scrape                  Magical Malindi,  Montville. QLD
# 3  city scrape  Queen Bedroom in shared house - walk, swim, surf
# 4  city scrape        Bewell Eco Cottage - Sunshine Ridge Cooroy
#
#                                          description  \
# 0  Accommodates up to 7 guests! Beautiful tropica...
# ...

# %%
others_list = [
    "id", "listing_url"
]

# %%
listings_df["picture_url"]
# Out:
# 0       https://a0.muscache.com/pictures/f53ed4a6-b175...
# 1       https://a0.muscache.com/pictures/miso/Hosting-...
# 2       https://a0.muscache.com/pictures/miso/Hosting-...
# 3       https://a0.muscache.com/pictures/19494015/09e3...
# 4       https://a0.muscache.com/pictures/c0bf6ac3-2d43...
#                               ...
# 7120    https://a0.muscache.com/pictures/miso/Hosting-...
# 7121    https://a0.muscache.com/pictures/miso/Hosting-...
# 7122    https://a0.muscache.com/pictures/miso/Hosting-...
# 7123    https://a0.muscache.com/pictures/miso/Hosting-...
# 7124    https://a0.muscache.com/pictures/miso/Hosting-...
# Name: picture_url, Length: 7125, dtype: object

# %%
listings_df["source"].value_counts()
# Out:
# source
# city scrape        6398
# previous scrape     727
# Name: count, dtype: int64

# %%
listings_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
import re

# %%
host_columns, reviews_columns = [], [] 
for feature in listings_df.columns:
    if re.search("^host_.*", feature): 
        host_columns.append(feature)
    elif re.search("^review.*", feature):
        print(feature)
        reviews_columns.append(feature)
print(reviews_columns)
# Out:
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# reviews_per_month
# ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'reviews_per_month']

# %%
reviews_listings = listings_df.loc[:, reviews_columns]
reviews_listings
# Out:
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     4.76                    4.74                       4.89
# 1                     4.84                    4.86                       4.65
# 2                     4.96                    4.97                       4.92
# 3                     4.68                    4.74                       4.59
# 4                     4.93                    4.94                       4.85
# ...                    ...                     ...                        ...
# 7120                   NaN                     NaN                        NaN
# 7121                   NaN                     NaN                        NaN
# 7122                   NaN                     NaN                        NaN
# 7123                   NaN                     NaN                        NaN
# 7124                   NaN                     NaN                        NaN
#
# ...

# %%
host_delete_columns = [
    "id", "url", "name", "location", "about", "thumbnail_url", "picture_url", 
]
host_final_delete_columns = [f"host_{feature}" for feature in host_delete_columns]
print(host_final_delete_columns)
# Out:
# ['host_id', 'host_url', 'host_name', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url']

# %%
listings_df.iloc[:, 103:20]
# Out:
#                                          host_url     host_name  host_since  \
# 0        https://www.airbnb.com/users/show/850132       Maureen  2011-07-21
# 1       https://www.airbnb.com/users/show/1547968           Ben  2011-12-29
# 2        https://www.airbnb.com/users/show/603365  Tony & Patty  2011-05-19
# 3       https://www.airbnb.com/users/show/2173713       Lorelle  2012-04-19
# 4       https://www.airbnb.com/users/show/3355245  Anne Therese  2012-08-23
# ...                                           ...           ...         ...
# 7120  https://www.airbnb.com/users/show/154273143       Rebekah  2017-10-12
# 7121  https://www.airbnb.com/users/show/342848966    Noosa Blue  2020-03-30
# 7122  https://www.airbnb.com/users/show/327130252       Melanie  2020-01-13
# 7123  https://www.airbnb.com/users/show/444837087     Alexandra  2022-02-13
# 7124  https://www.airbnb.com/users/show/154273143       Rebekah  2017-10-12
#
#                   host_location  \
# ...
